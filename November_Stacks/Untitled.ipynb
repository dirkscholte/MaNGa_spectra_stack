# %%
from os import listdir
from os.path import isfile, join

mypath = '/pscratch/sd/m/marta_r/MaNGa_spectra_stack/November_Stacks/'

onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
len(onlyfiles)
# Out:
# 100

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
for counter, data_test in enumerate(onlyfiles):
    
    #try: 
        data = pd.read_csv(data_test)
        
        col_array = data.columns
        
        
        
        if counter %5 == 0:
            fig, ax = plt.subplots(figsize = (18,5))
            for position, wave in enumerate(col_array):

                flux = 'flux_radius_{}'.format(position+1)

                wavelength =  'Wavelength_radius_{}'.format(position+1)
                
                if str(wavelength) in data.columns:
                    
                    plt.plot(data[str(wavelength)], data[str(flux)])
                
            plt.title('Spectra test {}'.format(data_test))
            plt.show()

            #print(data.columns)
            print('NEXT')
        
    #except: 
     #   print('ERROR ON: ', data_test)
# Out:
# NEXT
# NEXT
# NEXT
# NEXT
# NEXT
# NEXT
# NEXT
# NEXT
# NEXT
# NEXT
# NEXT
# NEXT
# NEXT
# NEXT
# NEXT
# NEXT
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[4], line 4
#       1 for counter, data_test in enumerate(onlyfiles):
#       2
#       3     #try:
# ----> 4         data = pd.read_csv(data_test)
#       6         col_array = data.columns
#      10         if counter %5 == 0:
#
# ...
