# %% [markdown]
# # Running FastSpecFit

# %%
import os
import glob
from matplotlib import pyplot as plt

# %% [markdown]
# ## Installing FastSpecFit (my local version as the stackfitting routine is temporarily broken in the main version)

# %%
! source /global/cfs/cdirs/desi/software/desi_environment.sh 23.1
! module swap desispec/0.59.2
! python -m pip install /global/homes/d/dscholte/packages/fastspecfit/
# Out:
# The following have been reloaded with a version change:
#   1) QuasarNP/0.1.5 => QuasarNP/0.1.3
#   2) desimeter/main => desimeter/0.7.0
#   3) desimodel/main => desimodel/0.18.0
#   4) desimodules/master => desimodules/23.1
#   5) desisim/main => desisim/0.37.1
#   6) desispec/main => desispec/0.56.5
#   7) desisurvey/main => desisurvey/0.19.0
#   8) desitarget/main => desitarget/2.6.0
#   9) desiutil/main => desiutil/3.2.6
#  10) fiberassign/main => fiberassign/5.7.0
#  11) gpu_specter/main => gpu_specter/0.2.0
#  12) prospect/main => prospect/1.2.4
#  13) redrock-templates/main => redrock-templates/0.8
#  14) redrock/main => redrock/0.17.0
#  15) simqso/main => simqso/v1.3.0
#  16) specex/main => specex/0.8.5
#  17) speclite/main => speclite/v0.16
#  18) specprod-db/main => specprod-db/1.1.0
#  19) specsim/main => specsim/v0.16
#  20) specter/main => specter/0.10.1
#  21) surveysim/main => surveysim/0.12.5
#
#
# The following have been reloaded with a version change:
#   1) desispec/main => desispec/0.59.2
#
# Defaulting to user installation because normal site-packages is not writeable
# Processing /global/homes/d/dscholte/packages/fastspecfit
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: fastspecfit
#   Building wheel for fastspecfit (setup.py) ... done
#   Created wheel for fastspecfit: filename=fastspecfit-2.4.2.dev1233-py3-none-any.whl size=4821485 sha256=ae539b4c22eef9fcfeaf709a323359cee48dc67d705bca9117d36baba390e600
#   Stored in directory: /tmp/pip-ephem-wheel-cache-byvfwin0/wheels/78/b3/0f/0af0f77607e583d9816e72acf675e6ef5393180419613dabe9
# Successfully built fastspecfit
# Installing collected packages: fastspecfit
#   Attempting uninstall: fastspecfit
#     Found existing installation: fastspecfit 2.4.2.dev1233
#     Uninstalling fastspecfit-2.4.2.dev1233:
#       Successfully uninstalled fastspecfit-2.4.2.dev1233
# Successfully installed fastspecfit-2.4.2.dev1233

# %%
def run_fastspecfit_on(filename):
    os.system('stackfit ' + filename + ' -o ' + 'stackfit_' + filename + ' --mp 1')
    return

def run_fastqa_on(filename):
    os.system('fastqa ' + 'stackfit_' + filename + ' --redrockfiles ' + filename + ' -o qa_plots/' + filename[:-5] + ' --stackfit')
    return

# %%
! pwd
# Out:
# /pscratch/sd/d/dscholte/MaNGa_spectra_stack/Double_peak_correction

# %%
spectra_files = glob.glob('Spectra*.fits')

# %%
spectra_files
# Out:
# ['Spectra_stacks_Nov_8996-12701.fits',
#  'Spectra_stacks_Nov_8241-9101.fits',
#  'Spectra_stacks_Nov_9042-9101.fits',
#  'Spectra_stacks_Nov_8144-6104.fits',
#  'Spectra_stacks_Nov_8600-12702.fits']

# %% [markdown]
# ### Run FastSpecFit

# %%
[run_fastspecfit_on(filename) for filename in spectra_files]
# Out:
# INFO:fastspecfit.py:119:parse: /global/homes/d/dscholte/.local/bin/stackfit Spectra_stacks_Nov_8996-12701.fits -o stackfit_Spectra_stacks_Nov_8996-12701.fits --mp 1
# INFO:io.py:1258:read_stacked: Reading and parsing 1 unique stackfile(s).
# INFO:io.py:1278:read_stacked: specprod=stacked, coadd_type=stacked, survey=stacked, program=stacked, healpix=0
# INFO:io.py:1343:read_stacked: Reading 5 spectra from Spectra_stacks_Nov_8996-12701.fits
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 0 [stackid 1 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 1 [stackid 2 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 2 [stackid 3 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 3 [stackid 4 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 4 [stackid 5 z=0.000000].
# INFO:fastspecfit.py:200:fastspec: Reading and unpacking 5 spectra to be fitted took 1.80 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 0 [stackid 1, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.97 seconds.
# WARNING:continuum.py:2114:continuum_specfit: vdisp signal-to-noise 0.52 is less than one; adopting vdisp=125 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 0.66 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.608+/-1.073, Model Dn(4000)=1.670
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-5.071 Msun, Msdss_r=0.00 mag, A(V)=2.517, Age=12.821 Gyr, SFR=0.000 Msun/yr, Z/Zsun=0.138
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 2.88 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.90 seconds [niter=22, rchi2=0.0001].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.05 seconds [niter=22, rchi2=0.0001].
# INFO:emlines.py:2491:emline_specfit: Dropping broad-line model: delta-chi2=0.0 < delta-ndof=8
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.641 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.06 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 1 [stackid 2, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.46 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=160.9+/-7.2 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.22 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.598+/-0.022, Model Dn(4000)=1.667
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.135 Msun, Msdss_r=0.00 mag, A(V)=2.208, Age=5.309 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.023
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.11 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.61 seconds [niter=26, rchi2=0.3206].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.75 seconds [niter=37, rchi2=0.3134].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 91.1 km/s < 250 km/s (delta-chi2=29.8, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.626 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.47 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 2 [stackid 3, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.36 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=271.0+/-6.8 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.53 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.577+/-0.010, Model Dn(4000)=1.649
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.01 Msun, Msdss_r=0.00 mag, A(V)=1.989, Age=5.175 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.091
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.41 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.66 seconds [niter=20, rchi2=1.5090].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.66 seconds [niter=32, rchi2=1.4976].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 89.7 km/s < 250 km/s (delta-chi2=83.5, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.598 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.44 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 3 [stackid 4, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.29 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=277.8+/-3.3 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.51 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.547+/-0.005, Model Dn(4000)=1.603
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-3.813 Msun, Msdss_r=0.00 mag, A(V)=2.041, Age=4.856 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.130
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.33 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.65 seconds [niter=23, rchi2=6.6773].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.20 seconds [niter=25, rchi2=6.6326].
# INFO:emlines.py:2483:emline_specfit: Adopting broad-line model:
# INFO:emlines.py:2484:emline_specfit:   delta-chi2=333.2 > delta-ndof=8
# INFO:emlines.py:2485:emline_specfit:   sigma_broad=351.7 km/s, sigma_narrow=95.6 km/s
# INFO:emlines.py:2487:emline_specfit:   S/N (hbeta_broad) = 3.7, S/N (halpha_broad) = 2.9 > 3
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.569 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 1.95 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 4 [stackid 5, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.25 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=321.2+/-3.8 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.65 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.535+/-0.004, Model Dn(4000)=1.566
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-3.849 Msun, Msdss_r=0.00 mag, A(V)=2.200, Age=3.624 Gyr, SFR=0.000 Msun/yr, Z/Zsun=0.005
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.48 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.49 seconds [niter=19, rchi2=9.5560].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.30 seconds [niter=21, rchi2=9.4292].
# INFO:emlines.py:2483:emline_specfit: Adopting broad-line model:
# INFO:emlines.py:2484:emline_specfit:   delta-chi2=859.3 > delta-ndof=8
# INFO:emlines.py:2485:emline_specfit:   sigma_broad=362.0 km/s, sigma_narrow=93.5 km/s
# INFO:emlines.py:2487:emline_specfit:   S/N (hbeta_broad) = 4.8, S/N (halpha_broad) = 3.7 > 3
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.551 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 1.90 seconds.
# INFO:fastspecfit.py:245:fastspec: Fitting 5 object(s) took 30.80 seconds.
# INFO:io.py:1882:write_fastspecfit: Writing 5 objects to stackfit_Spectra_stacks_Nov_8996-12701.fits
# INFO:io.py:1950:write_fastspecfit: Writing out took 1.79 seconds.
# INFO:fastspecfit.py:119:parse: /global/homes/d/dscholte/.local/bin/stackfit Spectra_stacks_Nov_8241-9101.fits -o stackfit_Spectra_stacks_Nov_8241-9101.fits --mp 1
# INFO:io.py:1258:read_stacked: Reading and parsing 1 unique stackfile(s).
# INFO:io.py:1278:read_stacked: specprod=stacked, coadd_type=stacked, survey=stacked, program=stacked, healpix=0
# INFO:io.py:1343:read_stacked: Reading 6 spectra from Spectra_stacks_Nov_8241-9101.fits
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 0 [stackid 1 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 1 [stackid 2 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 2 [stackid 3 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 3 [stackid 4 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 4 [stackid 5 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 5 [stackid 6 z=0.000000].
# INFO:fastspecfit.py:200:fastspec: Reading and unpacking 6 spectra to be fitted took 1.63 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 0 [stackid 1, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.78 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=226.8+/-20.7 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.39 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.539+/-0.036, Model Dn(4000)=1.575
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.322 Msun, Msdss_r=0.00 mag, A(V)=2.416, Age=7.172 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.324
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.67 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.93 seconds [niter=20, rchi2=0.0829].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.67 seconds [niter=31, rchi2=0.0788].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 137.2 km/s < 250 km/s (delta-chi2=25.5, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.568 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.71 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 1 [stackid 2, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.33 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=274.5+/-14.0 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.50 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.545+/-0.020, Model Dn(4000)=1.549
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-3.957 Msun, Msdss_r=0.00 mag, A(V)=2.754, Age=9.693 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.640
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.36 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.66 seconds [niter=21, rchi2=0.2943].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.46 seconds [niter=31, rchi2=0.2898].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 151.3 km/s < 250 km/s (delta-chi2=28.8, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.566 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.23 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 2 [stackid 3, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.22 seconds.
# INFO:continuum.py:2122:continuum_specfit: Finding vdisp failed; adopting vdisp=125 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 0.56 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.550+/-0.011, Model Dn(4000)=1.482
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-3.633 Msun, Msdss_r=0.00 mag, A(V)=2.926, Age=11.729 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.850
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 2.02 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.73 seconds [niter=22, rchi2=1.7431].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.61 seconds [niter=25, rchi2=1.7004].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 187.3 km/s < 250 km/s (delta-chi2=270.4, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.570 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.44 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 3 [stackid 4, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.25 seconds.
# INFO:continuum.py:2122:continuum_specfit: Finding vdisp failed; adopting vdisp=125 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 0.54 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.548+/-0.011, Model Dn(4000)=1.485
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.023 Msun, Msdss_r=0.00 mag, A(V)=2.312, Age=7.964 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.508
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 2.03 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.69 seconds [niter=21, rchi2=2.3314].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.27 seconds [niter=21, rchi2=2.2956].
# INFO:emlines.py:2500:emline_specfit: Dropping broad-line model: S/N (hbeta_broad) = 2.0, S/N (halpha_broad) = 1.8 < 3
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.566 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.06 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 4 [stackid 5, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.26 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=311.7+/-10.2 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.39 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.537+/-0.012, Model Dn(4000)=1.586
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.157 Msun, Msdss_r=0.00 mag, A(V)=2.727, Age=2.608 Gyr, SFR=0.000 Msun/yr, Z/Zsun=0.209
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.19 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.55 seconds [niter=22, rchi2=1.5024].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.00 seconds [niter=20, rchi2=1.5009].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 148.8 km/s < 250 km/s (delta-chi2=12.0, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.554 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 1.65 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 5 [stackid 6, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.22 seconds.
# INFO:continuum.py:2122:continuum_specfit: Finding vdisp failed; adopting vdisp=125 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 0.55 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.499+/-0.013, Model Dn(4000)=1.479
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.39 Msun, Msdss_r=0.00 mag, A(V)=1.469, Age=6.885 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.292
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 2.01 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.55 seconds [niter=19, rchi2=1.8687].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.49 seconds [niter=25, rchi2=1.8431].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 117.1 km/s < 250 km/s (delta-chi2=171.9, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.518 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.15 seconds.
# INFO:fastspecfit.py:245:fastspec: Fitting 6 object(s) took 33.66 seconds.
# INFO:io.py:1882:write_fastspecfit: Writing 6 objects to stackfit_Spectra_stacks_Nov_8241-9101.fits
# INFO:io.py:1950:write_fastspecfit: Writing out took 1.78 seconds.
# INFO:fastspecfit.py:119:parse: /global/homes/d/dscholte/.local/bin/stackfit Spectra_stacks_Nov_9042-9101.fits -o stackfit_Spectra_stacks_Nov_9042-9101.fits --mp 1
# INFO:io.py:1258:read_stacked: Reading and parsing 1 unique stackfile(s).
# INFO:io.py:1278:read_stacked: specprod=stacked, coadd_type=stacked, survey=stacked, program=stacked, healpix=0
# INFO:io.py:1343:read_stacked: Reading 7 spectra from Spectra_stacks_Nov_9042-9101.fits
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 0 [stackid 1 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 1 [stackid 2 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 2 [stackid 3 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 3 [stackid 4 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 4 [stackid 5 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 5 [stackid 6 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 6 [stackid 7 z=0.000000].
# INFO:fastspecfit.py:200:fastspec: Reading and unpacking 7 spectra to be fitted took 1.65 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 0 [stackid 1, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.85 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=207.3+/-32.9 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.30 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.612+/-0.075, Model Dn(4000)=1.602
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.597 Msun, Msdss_r=0.00 mag, A(V)=1.992, Age=9.719 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.527
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.63 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.88 seconds [niter=20, rchi2=0.0650].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.61 seconds [niter=31, rchi2=0.0649].
# INFO:emlines.py:2491:emline_specfit: Dropping broad-line model: delta-chi2=1.2 < delta-ndof=8
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.640 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.65 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 1 [stackid 2, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.33 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=286.6+/-24.4 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.54 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.618+/-0.041, Model Dn(4000)=1.602
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.349 Msun, Msdss_r=0.00 mag, A(V)=2.416, Age=9.277 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.621
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.42 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.42 seconds [niter=17, rchi2=0.2051].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.43 seconds [niter=29, rchi2=0.1962].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 159.9 km/s < 250 km/s (delta-chi2=54.8, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.642 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 1.96 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 2 [stackid 3, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.32 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=295.6+/-12.9 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.60 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.611+/-0.017, Model Dn(4000)=1.593
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.029 Msun, Msdss_r=0.00 mag, A(V)=2.385, Age=10.104 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.700
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.49 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.65 seconds [niter=15, rchi2=1.2760].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.16 seconds [niter=26, rchi2=1.2730].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 247.6 km/s < 250 km/s (delta-chi2=31.0, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.629 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 1.92 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 3 [stackid 4, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.27 seconds.
# INFO:continuum.py:2122:continuum_specfit: Finding vdisp failed; adopting vdisp=125 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 0.62 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.592+/-0.013, Model Dn(4000)=1.510
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.001 Msun, Msdss_r=0.00 mag, A(V)=1.641, Age=10.260 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.469
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 2.14 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.61 seconds [niter=14, rchi2=2.2986].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.17 seconds [niter=28, rchi2=2.2677].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 122.8 km/s < 250 km/s (delta-chi2=208.0, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.606 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 1.89 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 4 [stackid 5, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.27 seconds.
# INFO:continuum.py:2122:continuum_specfit: Finding vdisp failed; adopting vdisp=125 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 0.61 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.563+/-0.013, Model Dn(4000)=1.474
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.12 Msun, Msdss_r=0.00 mag, A(V)=1.495, Age=10.263 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.695
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 2.11 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.67 seconds [niter=25, rchi2=0.8426].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 0.97 seconds [niter=23, rchi2=0.7995].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 203.9 km/s < 250 km/s (delta-chi2=262.7, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.580 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 1.75 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 5 [stackid 6, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.32 seconds.
# INFO:continuum.py:2122:continuum_specfit: Finding vdisp failed; adopting vdisp=125 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 0.61 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.520+/-0.007, Model Dn(4000)=1.455
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.159 Msun, Msdss_r=0.00 mag, A(V)=1.280, Age=8.171 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.619
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 2.16 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.53 seconds [niter=24, rchi2=2.4124].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.26 seconds [niter=26, rchi2=2.2593].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 198.1 km/s < 250 km/s (delta-chi2=928.6, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.535 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 1.89 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 6 [stackid 7, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.27 seconds.
# INFO:continuum.py:2122:continuum_specfit: Finding vdisp failed; adopting vdisp=125 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 0.61 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.481+/-0.006, Model Dn(4000)=1.418
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.269 Msun, Msdss_r=0.00 mag, A(V)=0.978, Age=8.042 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.719
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 2.12 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.59 seconds [niter=19, rchi2=10.9576].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.46 seconds [niter=26, rchi2=10.9655].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 7.2 km/s < 250 km/s (delta-chi2=59.3, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.494 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.16 seconds.
# INFO:fastspecfit.py:245:fastspec: Fitting 7 object(s) took 38.08 seconds.
# INFO:io.py:1882:write_fastspecfit: Writing 7 objects to stackfit_Spectra_stacks_Nov_9042-9101.fits
# INFO:io.py:1950:write_fastspecfit: Writing out took 1.89 seconds.
# INFO:fastspecfit.py:119:parse: /global/homes/d/dscholte/.local/bin/stackfit Spectra_stacks_Nov_8144-6104.fits -o stackfit_Spectra_stacks_Nov_8144-6104.fits --mp 1
# INFO:io.py:1258:read_stacked: Reading and parsing 1 unique stackfile(s).
# INFO:io.py:1278:read_stacked: specprod=stacked, coadd_type=stacked, survey=stacked, program=stacked, healpix=0
# INFO:io.py:1343:read_stacked: Reading 6 spectra from Spectra_stacks_Nov_8144-6104.fits
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 0 [stackid 1 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 1 [stackid 2 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 2 [stackid 3 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 3 [stackid 4 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 4 [stackid 5 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 5 [stackid 6 z=0.000000].
# INFO:fastspecfit.py:200:fastspec: Reading and unpacking 6 spectra to be fitted took 1.59 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 0 [stackid 1, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.84 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=209.1+/-18.4 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.33 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.855+/-0.077, Model Dn(4000)=1.914
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.595 Msun, Msdss_r=0.00 mag, A(V)=0.845, Age=8.097 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.245
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.65 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.84 seconds [niter=13, rchi2=0.2144].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.01 seconds [niter=21, rchi2=0.2145].
# INFO:emlines.py:2491:emline_specfit: Dropping broad-line model: delta-chi2=1.3 < delta-ndof=8
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.874 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 1.96 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 1 [stackid 2, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.37 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=211.6+/-9.3 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.35 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.826+/-0.038, Model Dn(4000)=1.865
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.401 Msun, Msdss_r=0.00 mag, A(V)=0.914, Age=7.392 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.257
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.21 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.48 seconds [niter=13, rchi2=0.6137].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.45 seconds [niter=20, rchi2=0.6139].
# INFO:emlines.py:2491:emline_specfit: Dropping broad-line model: delta-chi2=4.8 < delta-ndof=8
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.845 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.04 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 2 [stackid 3, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.36 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=246.7+/-6.2 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.47 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.767+/-0.015, Model Dn(4000)=1.772
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.156 Msun, Msdss_r=0.00 mag, A(V)=0.914, Age=7.337 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.300
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.35 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.34 seconds [niter=19, rchi2=2.3598].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.35 seconds [niter=24, rchi2=2.3592].
# INFO:emlines.py:2500:emline_specfit: Dropping broad-line model: S/N (hbeta_broad) = 0.1, S/N (halpha_broad) = 1.0 < 3
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.781 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 1.80 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 3 [stackid 4, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.34 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=252.0+/-6.3 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# ...
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 0.74 seconds [niter=21, rchi2=12.9987].
# INFO:emlines.py:2491:emline_specfit: Dropping broad-line model: delta-chi2=0.7 < delta-ndof=8
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.509 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 1.36 seconds.
# INFO:fastspecfit.py:245:fastspec: Fitting 6 object(s) took 34.77 seconds.
# INFO:io.py:1882:write_fastspecfit: Writing 6 objects to stackfit_Spectra_stacks_Nov_8144-6104.fits
# INFO:io.py:1950:write_fastspecfit: Writing out took 1.81 seconds.
# INFO:fastspecfit.py:119:parse: /global/homes/d/dscholte/.local/bin/stackfit Spectra_stacks_Nov_8600-12702.fits -o stackfit_Spectra_stacks_Nov_8600-12702.fits --mp 1
# INFO:io.py:1258:read_stacked: Reading and parsing 1 unique stackfile(s).
# INFO:io.py:1278:read_stacked: specprod=stacked, coadd_type=stacked, survey=stacked, program=stacked, healpix=0
# INFO:io.py:1343:read_stacked: Reading 7 spectra from Spectra_stacks_Nov_8600-12702.fits
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 0 [stackid 1 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 1 [stackid 2 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 2 [stackid 3 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 3 [stackid 4 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 4 [stackid 5 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 5 [stackid 6 z=0.000000].
# INFO:io.py:305:unpack_one_stacked_spectrum: Pre-processing object 6 [stackid 7 z=0.000000].
# INFO:fastspecfit.py:200:fastspec: Reading and unpacking 7 spectra to be fitted took 1.74 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 0 [stackid 1, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.84 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=160.9+/-39.2 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.20 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.514+/-0.112, Model Dn(4000)=1.611
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-5.062 Msun, Msdss_r=0.00 mag, A(V)=1.001, Age=8.775 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.521
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.47 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.58 seconds [niter=16, rchi2=0.0679].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.15 seconds [niter=21, rchi2=0.0680].
# INFO:emlines.py:2491:emline_specfit: Dropping broad-line model: delta-chi2=0.3 < delta-ndof=8
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.548 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 1.88 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 1 [stackid 2, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.35 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=199.7+/-23.1 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.35 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.507+/-0.042, Model Dn(4000)=1.593
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.702 Msun, Msdss_r=0.00 mag, A(V)=1.189, Age=9.904 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.604
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.18 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.60 seconds [niter=20, rchi2=0.2344].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.52 seconds [niter=22, rchi2=0.2356].
# INFO:emlines.py:2491:emline_specfit: Dropping broad-line model: delta-chi2=1.1 < delta-ndof=8
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.539 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.22 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 2 [stackid 3, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.30 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=248.0+/-10.3 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.42 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.483+/-0.015, Model Dn(4000)=1.565
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.379 Msun, Msdss_r=0.00 mag, A(V)=1.196, Age=10.057 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.680
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.21 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.85 seconds [niter=27, rchi2=2.2160].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.51 seconds [niter=28, rchi2=2.2135].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 106.1 km/s < 250 km/s (delta-chi2=37.8, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.512 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.47 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 3 [stackid 4, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.23 seconds.
# INFO:continuum.py:2118:continuum_specfit: Best-fitting vdisp=326.8+/-16.0 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 1.61 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.448+/-0.016, Model Dn(4000)=1.517
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.481 Msun, Msdss_r=0.00 mag, A(V)=1.113, Age=9.864 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.665
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 3.47 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 1.22 seconds [niter=34, rchi2=1.9054].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.65 seconds [niter=28, rchi2=1.9077].
# INFO:emlines.py:2491:emline_specfit: Dropping broad-line model: delta-chi2=7.3 < delta-ndof=8
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.470 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.98 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 4 [stackid 5, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.22 seconds.
# INFO:continuum.py:2122:continuum_specfit: Finding vdisp failed; adopting vdisp=125 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 0.61 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.416+/-0.010, Model Dn(4000)=1.430
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.383 Msun, Msdss_r=0.00 mag, A(V)=0.941, Age=9.375 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.671
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 2.07 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.71 seconds [niter=24, rchi2=5.5791].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.38 seconds [niter=24, rchi2=5.5573].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 99.0 km/s < 250 km/s (delta-chi2=190.6, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.435 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.19 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 5 [stackid 6, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.21 seconds.
# INFO:continuum.py:2122:continuum_specfit: Finding vdisp failed; adopting vdisp=125 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 0.59 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.389+/-0.007, Model Dn(4000)=1.411
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.317 Msun, Msdss_r=0.00 mag, A(V)=0.753, Age=11.148 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.813
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 2.04 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.78 seconds [niter=25, rchi2=13.7775].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.66 seconds [niter=25, rchi2=13.7284].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 99.3 km/s < 250 km/s (delta-chi2=399.4, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.405 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.55 seconds.
# INFO:fastspecfit.py:50:fastspec_one: Continuum- and emission-line fitting object 6 [stackid 7, z=0.000000].
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2107:continuum_specfit: Fitting for the velocity dispersion took 1.19 seconds.
# INFO:continuum.py:2122:continuum_specfit: Finding vdisp failed; adopting vdisp=125 km/s.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2157:continuum_specfit: Skipping aperture correction since no bands were fit.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2217:continuum_specfit: Final fitting with 192 models took 0.61 seconds.
# WARNING:continuum.py:1611:templates2data: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2251:continuum_specfit: Spectroscopic DN(4000)=1.356+/-0.004, Model Dn(4000)=1.383
# WARNING:continuum.py:1919:kcorr_and_absmag: Input redshift not defined, zero, or negative!
# WARNING:continuum.py:1849:continuum_fluxes: Input redshift not defined, zero, or negative!
# INFO:continuum.py:2319:continuum_specfit: Mstar=-4.218 Msun, Msdss_r=0.00 mag, A(V)=0.577, Age=12.323 Gyr, SFR=0.000 Msun/yr, Z/Zsun=-0.928
# INFO:continuum.py:2359:continuum_specfit: Continuum-fitting took 2.04 seconds.
# INFO:emlines.py:2406:emline_specfit: Line-fitting with no broad lines and 33 free parameters took 0.68 seconds [niter=21, rchi2=53.4684].
# INFO:emlines.py:2437:emline_specfit: Line-fitting with broad lines and 44 free parameters took 1.42 seconds [niter=25, rchi2=53.2747].
# INFO:emlines.py:2494:emline_specfit: Dropping broad-line model: Halpha_broad_sigma 101.6 km/s < 250 km/s (delta-chi2=1469.7, delta-ndof=8).
# INFO:emlines.py:2581:emline_specfit: Dn(4000)=1.370 in the emission-line subtracted spectrum.
# INFO:emlines.py:2622:emline_specfit: Emission-line fitting took 2.20 seconds.
# INFO:fastspecfit.py:245:fastspec: Fitting 7 object(s) took 40.76 seconds.
# INFO:io.py:1882:write_fastspecfit: Writing 7 objects to stackfit_Spectra_stacks_Nov_8600-12702.fits
# INFO:io.py:1950:write_fastspecfit: Writing out took 1.78 seconds.
# [None, None, None, None, None]

# %% [markdown]
# ### Run FastQA to generate diagnostic plots

# %%
[run_fastqa_on(filename) for filename in spectra_files]
